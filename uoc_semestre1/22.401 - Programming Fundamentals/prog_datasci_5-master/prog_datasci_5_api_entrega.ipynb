# %% [markdown]
# <div style="width: 100%; clear: both;">
#     <div style="float: left; width: 50%;">
#        <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
#     </div>
# </div>
#
# <div style="float: right; width: 50%;">
#     <p style="margin: 0; padding-top: 22px; text-align:right;">22.501 · Fundamentos de Programación</p>
#     <p style="margin: 0; text-align:right;">Grado en Ciencia de Datos Aplicada</p>
#     <p style="margin: 0; text-align:right; padding-button: 100px;">Estudios de Informática, Multimedia y Telecomunicación</p>
# </div>
#
# </div>
# <div style="width: 100%; clear: both;">
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# Unidad 5: Adquisición de datos en Python
# --------------------------------------
#
# Fundamentos de Programación
# ============================
#
#
# En este Notebook se encontraréis el conjunto de actividades evaluables como PEC de la asignatura. Veréis que cada una de ellas tiene asociada una puntuación, que indica el peso que tiene la actividad sobre la nota final de la PEC. Adicionalmente, hay un ejercicio opcional, que no tiene puntuación dentro de la PEC, pero que se valora al final del semestre de cara a conceder las matrículas de honor y redondear las notas finales. Podréis sacar la máxima nota de la PEC sin necesidad de hacer este ejercicio. El objetivo de este ejercicio es que sirva como pequeño reto para los estudiantes que quieran profundizar en el contenido de la asignatura.
#
# Veréis que todas las actividades de la PEC tienen una etiqueta, que indica los recursos necesarios para llevarla a cabo. Hay tres posibles etiquetas:
#
# * <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">NM</span> **Sólo materiales**: las herramientas necesarias para realizar la actividad se pueden encontrar en los materiales de la asignatura.
#
# * <span style = "font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Consulta externa guiada**: la actividad puede requerir hacer uso de herramientas que no se encuentran en los materiales de la asignatura, pero el enunciado contiene indicaciones de dónde o cómo encontrar la información adicional necesaria para resolver la actividad.
#
# * <span style = "font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px;">EI</span> **Consulta externa independiente**: la actividad puede requerir hacer uso de herramientas que no se encuentran en los materiales de la asignatura, y el enunciado puede no incluir la descripción de dónde o cómo encontrar esta información adicional. Será necesario que el estudiante busque esta información utilizando los recursos que se han explicado en la asignatura.
#
# Es importante notar que estas etiquetas no indican el nivel de dificultad del ejercicio, sino únicamente la necesidad de consulta de documentación externa para su resolución. Además, recordad que las **etiquetas son informativas**, pero podréis consultar referencias externas en cualquier momento (aunque no se indique explícitamente) o puede ser que podáis hacer una actividad sin consultar ningún tipo de documentación. Por ejemplo, para resolver una actividad que sólo requiera los materiales de la asignatura, puedéis consultar referencias externas si queréis, ya sea tanto para ayudaros en la resolución como para ampliar el conocimiento!
#
# En cuanto a la consulta de documentación externa en la resolución de los ejercicios, recordad **citar siempre la bibliografía utilizada** para resolver cada actividad.
#
# ---

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Hemos visto el uso de la librería [Requests](http://docs.python-requests.org/) para realizar peticiones a la Web API de manera manual.
#
# Mediante esta librería podemos realizar solicitudes como en el ejemplo que hemos visto de [postcodes.io](http://postcodes.io).
#
#
# Hemos visto que, al hacer una petición a una web o API, recuperamos un objeto que contiene, entre otros, los siguientes atributos: `status.code`,`content`, `headers`.
#
# Implementa una función de forma que:
#
# 1. acepte una *url* y, en caso de que el `status.code`  sea correcto, imprima el nombre de cada uno de los `header` junto con su contenido.
#
# 1. En caso  de que el `status.code` contenga un código de error, no debe imprimir los `header` sino el código de error recibido.
#
# 1. La función debe retornar el código de error a la salida.
#
#
# Prueba la función con las siguientes URLs:
#
# - http://wikipedia.org
# - http://google.com/thehearthisflat
#
#
# **(1 punto)**
# <span style="font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px; ">EI</span>

# %%
import requests
import json

# Respuesta
def json_print(json_data, limit=None):
    if isinstance(json_data, (str)):
        json_data = json.loads(json_data)
    nice = json.dumps(json_data, sort_keys=True, indent=3, separators=(',', ': '))
    print("\n".join(nice.split("\n")[0:limit]))
    if limit is not None:
        print("[...]")
        
def responseURL(url):
    response = requests.get(url)
    
    if response.status_code == 200:
        print("------ Response Header ------")
        json_print(dict(response.headers))
    else:
        print("------ Status Code ------")
        print(response.status_code)

responseURL('http://wikipedia.org')
responseURL('http://google.com/thehearthisflat')
# Out:
# ------ Response Header ------
# {
#    "Accept-Ranges": "bytes",
#    "Age": "31634",
#    "Cache-Control": "s-maxage=86400, must-revalidate, max-age=3600",
#    "Connection": "keep-alive",
#    "Content-Encoding": "gzip",
#    "Content-Length": "18727",
#    "Content-Type": "text/html",
#    "Date": "Tue, 30 Nov 2021 01:39:48 GMT",
#    "ETag": "W/\"1365f-5d04989482e72\"",
#    "Last-Modified": "Mon, 08 Nov 2021 16:32:17 GMT",
#    "NEL": "{ \"report_to\": \"wm_nel\", \"max_age\": 86400, \"failure_fraction\": 0.05, \"success_fraction\": 0.0}",
#    "Permissions-Policy": "interest-cohort=()",
#    "Report-To": "{ \"group\": \"wm_nel\", \"max_age\": 86400, \"endpoints\": [{ \"url\": \"https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0\" }] }",
#    "Server": "ATS/8.0.8",
#    "Server-Timing": "cache;desc=\"hit-front\", host;desc=\"cp3054\"",
#    "Strict-Transport-Security": "max-age=106384710; includeSubDomains; preload",
#    "Vary": "Accept-Encoding",
#    "X-Cache": "cp3062 hit, cp3054 hit/642643",
#    "X-Cache-Status": "hit-front",
#    "X-Client-IP": "88.19.242.83"
# }
# ------ Status Code ------
# 404

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Para cada una de las siguientes direcciones:
#
# 1. https://cat-bounce.com
# 1. https://www.boredapi.com/api/
#
# mediante los servicios de `requests`, muestra:
#
# - La longitud del contenido de la dirección web.
# - El contenido de la dirección web, limitando la salida hasta 1000 caracteres.
#
# Accede a cada una de las direcciones con tu ordenador y observa el contenido en el navegador con el texto de la web. ¿Cuál es la diferencia en el contenido de la segunda dirección respecto a las  primera?
#
# **(1  punto)** <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">NM</span>

# %%
# Respuesta
response = requests.get('https://cat-bounce.com')
print(len(str(response.text)))
print(response.text[:1000])

response = requests.get('https://www.boredapi.com/api/')
print(len(str(response.text)))
print(response.text[:1000])

# En la primera URL podemos ver una pagina web completa y en la segunda lo 
# unico que vemos son datos en formato JSON con todo el resto en blanco.
# Out:
# 5737
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8">
#     <title>CAT BOUNCE!</title>
#
#     <!-- META -->
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta name="description" content="Cat Bounce! A website of bouncing cats.">
#
#     <!-- Facebook -->
#     <meta property="og:title" content="CAT BOUNCE!" />
#     <meta property="og:url" content="https://www.cat-bounce.com" />
#     <meta property="og:site_name" content="CAT BOUNCE!" />
#     <meta property="og:type" content="website" />
#     <meta property="og:description" content="It's Cat Bounce, what more do you need to know?" />
#     <meta property="og:image" content="https://www.cat-bounce.com/catbounce.png" />
#
#     <!-- Twitter -->
#     <meta name="twitter:card" content="summary">
#     <meta name="twitter:title" content="CAT BOUNCE!">
#     <meta name="twitter:url" content="https://www.cat-bounce.com">
#     <meta name="twitter:description" content="It's Cat Bounce, what more do you need to know?">
# 23
# {"message":"Bored API"}

# %% [markdown]
# ### Ejercicio 3
#
# En este ejercicio lucharemos un poco contra el aburrimiento.  Hay una API para justamente esto en la dirección https://www.boredapi.com, podéis ver la documentación de la API en https://www.boredapi.com/documentation.
#
#
# Por ejemplo, dada una llamada a esta dirección, obtenemos una actividad de forma aleatoria:
#
# | Call | Description |
# |: ---------: |: ------------------------------------ -------------------------------------------------- ------------ |
# | http://www.boredapi.com/api/activity/ | Random activity |
#
#
#
# a) Usa requests para llamar a la dirección anterior 100 veces. ¿Cuántas actividades aparecen para dos o más participantes?
#
#
# **(1 punto)** <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">NM</span>

# %%
# Respuesta
i = 1
participants = 0
while i <= 100:
    response = requests.get('http://www.boredapi.com/api/activity/')
    json_print(response.text)
    if response.json()["participants"] > 1:
        participants+=1
    i += 1
print(participants)
# Out:
# {
#    "accessibility": 0,
#    "activity": "Play a video game",
#    "key": "5534113",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.7,
#    "activity": "Visit your past teachers",
#    "key": "8238918",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "social"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Go to a music festival with some friends",
#    "key": "6482790",
#    "link": "",
#    "participants": 4,
#    "price": 0.4,
#    "type": "social"
# }
# {
#    "accessibility": 0,
#    "activity": "Listen to a new music genre",
#    "key": "4708863",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "music"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Go to a music festival with some friends",
#    "key": "6482790",
#    "link": "",
#    "participants": 4,
#    "price": 0.4,
#    "type": "social"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Go to an escape room",
#    "key": "5585829",
#    "link": "",
#    "participants": 4,
#    "price": 0.5,
#    "type": "social"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Prepare a dish from a foreign culture",
#    "key": "8061754",
#    "link": "",
#    "participants": 1,
#    "price": 0.2,
#    "type": "cooking"
# }
# {
#    "accessibility": 1,
#    "activity": "Do a jigsaw puzzle",
#    "key": "8550768",
#    "link": "https://en.wikipedia.org/wiki/Jigsaw_puzzle",
#    "participants": 1,
#    "price": 0.1,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.05,
#    "activity": "Learn how to fold a paper crane",
#    "key": "3136036",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "education"
# }
# {
#    "accessibility": 0.35,
#    "activity": "Start a garden",
#    "key": "1934228",
#    "link": "",
#    "participants": 1,
#    "price": 0.3,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.15,
#    "activity": "Take a class at your local community center that interests you",
#    "key": "8750692",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "education"
# }
# {
#    "accessibility": 0.12,
#    "activity": "Listen to a new podcast",
#    "key": "4124860",
#    "link": "",
#    "participants": 1,
#    "price": 0.05,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Make bread from scratch",
#    "key": "4809815",
#    "link": "",
#    "participants": 1,
#    "price": 0.2,
#    "type": "cooking"
# }
# {
#    "accessibility": 0,
#    "activity": "Play a video game",
#    "key": "5534113",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "recreational"
# }
# {
#    "accessibility": 0,
#    "activity": "Color",
#    "key": "5322987",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Volunteer and help out at a senior center",
#    "key": "3920096",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "charity"
# }
# {
#    "accessibility": 0.8,
#    "activity": "Donate to your local food bank",
#    "key": "4150284",
#    "link": "",
#    "participants": 1,
#    "price": 0.5,
#    "type": "charity"
# }
# {
#    "accessibility": 0,
#    "activity": "Clean out your refrigerator",
#    "key": "9324336",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "busywork"
# }
# {
#    "accessibility": 0,
#    "activity": "Clean out your refrigerator",
#    "key": "9324336",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "busywork"
# }
# {
#    "accessibility": 0.05,
#    "activity": "Learn how to fold a paper crane",
#    "key": "3136036",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "education"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Take a spontaneous road trip with some friends",
#    "key": "2085321",
#    "link": "",
#    "participants": 4,
#    "price": 0.2,
#    "type": "social"
# }
# {
#    "accessibility": 0.8,
#    "activity": "Do something you used to do as a kid",
#    "key": "8827573",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.8,
#    "activity": "Memorize a favorite quote or poem",
#    "key": "9008639",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "education"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Pull a harmless prank on one of your friends",
#    "key": "1288934",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "social"
# }
# {
#    "accessibility": 1,
#    "activity": "Start a family tree",
#    "key": "6825484",
#    "link": "https://en.wikipedia.org/wiki/Family_tree",
#    "participants": 1,
#    "price": 0,
#    "type": "social"
# }
# {
#    "accessibility": 0,
#    "activity": "Listen to a new music genre",
#    "key": "4708863",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "music"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Make bread from scratch",
#    "key": "4809815",
#    "link": "",
#    "participants": 1,
#    "price": 0.2,
#    "type": "cooking"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Learn about the Golden Ratio",
#    "key": "2095681",
#    "link": "https://en.wikipedia.org/wiki/Golden_ratio",
#    "participants": 1,
#    "price": 0.1,
#    "type": "education"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Invite some friends over for a game night",
#    "key": "6613428",
#    "link": "",
#    "participants": 4,
#    "price": 0,
#    "type": "social"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Learn about the Golden Ratio",
#    "key": "2095681",
#    "link": "https://en.wikipedia.org/wiki/Golden_ratio",
#    "participants": 1,
#    "price": 0.1,
#    "type": "education"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Volunteer at your local food bank",
#    "key": "2055368",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "charity"
# }
# {
#    "accessibility": 0.9,
#    "activity": "Do yoga",
#    "key": "4688012",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.35,
#    "activity": "Donate blood at a local blood center",
#    "key": "6509779",
#    "link": "https://www.redcross.org/give-blood",
#    "participants": 1,
#    "price": 0,
#    "type": "charity"
# }
# {
#    "accessibility": 0,
#    "activity": "Take a nap",
#    "key": "6184514",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Take a bubble bath",
#    "key": "2581372",
#    "link": "",
#    "participants": 1,
#    "price": 0.15,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Fill out a basketball bracket",
#    "key": "7806284",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.4,
#    "activity": "Repaint a room in your house",
#    "key": "4877086",
#    "link": "",
#    "participants": 1,
#    "price": 0.3,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Pull a harmless prank on one of your friends",
#    "key": "1288934",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "social"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Play a game of Monopoly",
#    "key": "1408058",
#    "link": "",
#    "participants": 4,
#    "price": 0.2,
#    "type": "social"
# }
# {
#    "accessibility": 0.9,
#    "activity": "Start a webinar on a topic of your choice",
#    "key": "6826029",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "education"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Play a game of Monopoly",
#    "key": "1408058",
#    "link": "",
#    "participants": 4,
#    "price": 0.2,
#    "type": "social"
# }
# {
#    "accessibility": 0.05,
#    "activity": "Learn a new recipe",
#    "key": "6553978",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "cooking"
# }
# {
#    "accessibility": 0.05,
#    "activity": "Meditate for five minutes",
#    "key": "3699502",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Volunteer at your local food bank",
#    "key": "2055368",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "charity"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Read a formal research paper on an interesting subject",
#    "key": "3352474",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "education"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Learn origami",
#    "key": "8394738",
#    "link": "",
#    "participants": 1,
#    "price": 0.2,
#    "type": "education"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Start a book you've never gotten around to reading",
#    "key": "7114122",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.25,
#    "activity": "Learn a new programming language",
#    "key": "5881028",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "education"
# }
# {
#    "accessibility": 0.15,
#    "activity": "Catch up with a friend over a lunch date",
#    "key": "5590133",
#    "link": "",
#    "participants": 2,
#    "price": 0.2,
#    "type": "social"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Bake pastries for you and your neighbor",
#    "key": "8125168",
#    "link": "",
#    "participants": 1,
#    "price": 0.4,
#    "type": "cooking"
# }
# {
#    "accessibility": 0,
#    "activity": "Watch a Khan Academy lecture on a subject of your choosing",
#    "key": "7154873",
#    "link": "https://www.khanacademy.org/",
#    "participants": 1,
#    "price": 0,
#    "type": "education"
# }
# {
#    "accessibility": 0.25,
#    "activity": "Learn how to iceskate or rollerskate",
#    "key": "5947957",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Take your dog on a walk",
#    "key": "9318514",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.02,
#    "activity": "Learn to write with your nondominant hand",
#    "key": "1645485",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.25,
#    "activity": "Learn Express.js",
#    "key": "3943506",
#    "link": "https://expressjs.com/",
#    "participants": 1,
#    "price": 0.1,
#    "type": "education"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Start a book you've never gotten around to reading",
#    "key": "7114122",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.8,
#    "activity": "Improve your touch typing",
#    "key": "2526437",
#    "link": "https://en.wikipedia.org/wiki/Touch_typing",
#    "participants": 1,
#    "price": 0,
#    "type": "busywork"
# }
# {
#    "accessibility": 0.8,
#    "activity": "Cook something together with someone",
#    "key": "1799120",
#    "link": "",
#    "participants": 2,
#    "price": 0.3,
#    "type": "cooking"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Go to a concert with local artists with some friends",
#    "key": "2211716",
#    "link": "",
#    "participants": 3,
#    "price": 0.4,
#    "type": "social"
# }
# {
#    "accessibility": 0.15,
#    "activity": "Take a class at your local community center that interests you",
#    "key": "8750692",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "education"
# }
# {
#    "accessibility": 0.5,
#    "activity": "Prepare a 72-hour kit",
#    "key": "4266522",
#    "link": "https://www.ready.gov/kit",
#    "participants": 1,
#    "price": 0.5,
#    "type": "busywork"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Find a DIY to do",
#    "key": "4981819",
#    "link": "",
#    "participants": 1,
#    "price": 0.4,
#    "type": "diy"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Learn calligraphy",
#    "key": "4565537",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "education"
# }
# {
#    "accessibility": 1,
#    "activity": "Learn how to beatbox",
#    "key": "8731710",
#    "link": "https://en.wikipedia.org/wiki/Beatboxing",
#    "participants": 1,
#    "price": 0,
#    "type": "recreational"
# }
# {
#    "accessibility": 0,
#    "activity": "Plan a trip to another country",
#    "key": "5554727",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Take your dog on a walk",
#    "key": "9318514",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0,
#    "activity": "Make a bucket list",
#    "key": "2735499",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "busywork"
# }
# {
#    "accessibility": 0.7,
#    "activity": "Visit your past teachers",
#    "key": "8238918",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "social"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Create and follow a savings plan",
#    "key": "9366464",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "busywork"
# }
# {
#    "accessibility": 0.9,
#    "activity": "Learn Javascript",
#    "key": "3469378",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "education"
# }
# {
#    "accessibility": 0,
#    "activity": "Create a meal plan for the coming week",
#    "key": "3491470",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "cooking"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Prepare a dish from a foreign culture",
#    "key": "8061754",
#    "link": "",
#    "participants": 1,
#    "price": 0.2,
#    "type": "cooking"
# }
# {
#    "accessibility": 0.35,
#    "activity": "Donate blood at a local blood center",
#    "key": "6509779",
#    "link": "https://www.redcross.org/give-blood",
#    "participants": 1,
#    "price": 0,
#    "type": "charity"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Have a picnic with some friends",
#    "key": "6813070",
#    "link": "",
#    "participants": 3,
#    "price": 0.1,
#    "type": "social"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Draw and color a Mandala",
#    "key": "4614092",
#    "link": "https://en.wikipedia.org/wiki/Mandala",
#    "participants": 1,
#    "price": 0.05,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Bake a pie with some friends",
#    "key": "3141592",
#    "link": "",
#    "participants": 3,
#    "price": 0.3,
#    "type": "cooking"
# }
# {
#    "accessibility": 0.4,
#    "activity": "Repaint a room in your house",
#    "key": "4877086",
#    "link": "",
#    "participants": 1,
#    "price": 0.3,
#    "type": "recreational"
# }
# {
#    "accessibility": 0,
#    "activity": "Start a daily journal",
#    "key": "8779876",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.8,
#    "activity": "Do something you used to do as a kid",
#    "key": "8827573",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Text a friend you haven't talked to in a long time",
#    "key": "6081071",
#    "link": "",
#    "participants": 2,
#    "price": 0.05,
#    "type": "social"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Have a football scrimmage with some friends",
#    "key": "1638604",
#    "link": "",
#    "participants": 8,
#    "price": 0,
#    "type": "social"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Learn calligraphy",
#    "key": "4565537",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "education"
# }
# {
#    "accessibility": 0.3,
#    "activity": "Prepare a dish from a foreign culture",
#    "key": "8061754",
#    "link": "",
#    "participants": 1,
#    "price": 0.2,
#    "type": "cooking"
# }
# {
#    "accessibility": 0,
#    "activity": "Make a bucket list",
#    "key": "2735499",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "busywork"
# }
# {
#    "accessibility": 0,
#    "activity": "Clean out your refrigerator",
#    "key": "9324336",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "busywork"
# }
# {
#    "accessibility": 1,
#    "activity": "Do a jigsaw puzzle",
#    "key": "8550768",
#    "link": "https://en.wikipedia.org/wiki/Jigsaw_puzzle",
#    "participants": 1,
#    "price": 0.1,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.4,
#    "activity": "Go to a concert with some friends",
#    "key": "4558850",
#    "link": "",
#    "participants": 4,
#    "price": 0.6,
#    "type": "social"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Go to the gym",
#    "key": "4387026",
#    "link": "",
#    "participants": 1,
#    "price": 0.2,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Have a picnic with some friends",
#    "key": "6813070",
#    "link": "",
#    "participants": 3,
#    "price": 0.1,
#    "type": "social"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Do something nice for someone you care about",
#    "key": "8321894",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "social"
# }
# {
#    "accessibility": 0,
#    "activity": "Make a new friend",
#    "key": "1000000",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "social"
# }
# {
#    "accessibility": 0.9,
#    "activity": "Do yoga",
#    "key": "4688012",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "recreational"
# }
# {
#    "accessibility": 0.05,
#    "activity": "Try a food you don't like",
#    "key": "6693574",
#    "link": "",
#    "participants": 1,
#    "price": 0.1,
#    "type": "recreational"
# }
# {
#    "accessibility": 0,
#    "activity": "Learn how to whistle with your fingers",
#    "key": "2790297",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "education"
# }
# {
#    "accessibility": 0.15,
#    "activity": "Teach your dog a new trick",
#    "key": "1668223",
#    "link": "",
#    "participants": 1,
#    "price": 0.05,
#    "type": "relaxation"
# }
# {
#    "accessibility": 0.05,
#    "activity": "Have a paper airplane contest with some friends",
#    "key": "8557562",
#    "link": "",
#    "participants": 4,
#    "price": 0.02,
#    "type": "social"
# }
# {
#    "accessibility": 0.1,
#    "activity": "Fill out a basketball bracket",
#    "key": "7806284",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "recreational"
# }
# {
#    "accessibility": 0,
#    "activity": "Write a song",
#    "key": "5188388",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "music"
# }
# {
#    "accessibility": 0.9,
#    "activity": "Start a webinar on a topic of your choice",
#    "key": "6826029",
#    "link": "",
#    "participants": 1,
#    "price": 0,
#    "type": "education"
# }
# {
#    "accessibility": 0.2,
#    "activity": "Make tie dye shirts",
#    "key": "8092359",
#    "link": "",
#    "participants": 1,
#    "price": 0.2,
#    "type": "diy"
# }
# 17

# %% [markdown]
# b) La documentación de la API indica que es posible hacer búsquedas incluyendo parámetros, como por ejemplo via la ruta:
#
# > /api/activity?minprice=:minprice&maxprice=:maxprice
#
# Escribe una función llamada `fun` que:
#
# 1. Tenga dos parámetros de entrada (`minprice`, `maxprice`).
#
# 2. Devuelva un diccionario solo con los elementos `price`, `activity` y `type`.
#
# Llama a esta función otras 100 veces y comprueba que todos los precios se ajustan a los valores de la llamada.
#
# **(1 punto)** <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">NM</span>

# %%
# Respuesta
def fun(minprice, maxprice):
    response = requests.get(f'http://www.boredapi.com/api/activity?minprice={minprice}&maxprice={maxprice}')
    print(response.json()['price'])
    print(response.json()['activity'])
    print(response.json()['type'])
    
i = 1
while i <= 100:
    fun(0.5, 3)
    i += 1
# Out:
# 0.8
# Go see a Broadway production
# recreational
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.8
# Go see a Broadway production
# recreational
# 0.5
# Go to an escape room
# social
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.5
# Donate to your local food bank
# charity
# 0.8
# Go see a Broadway production
# recreational
# 0.6
# Go to a concert with some friends
# social
# 0.55
# Learn to play a new instrument
# music
# 0.5
# Donate to your local food bank
# charity
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.5
# Donate to your local food bank
# charity
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.5
# Donate to your local food bank
# charity
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.8
# Go see a Broadway production
# recreational
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.6
# Learn the Chinese erhu
# music
# 0.6
# Go to a concert with some friends
# social
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.6
# Go to a concert with some friends
# social
# 0.5
# Go to an escape room
# social
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.6
# Go to a concert with some friends
# social
# 0.8
# Go see a Broadway production
# recreational
# 0.55
# Learn to play a new instrument
# music
# 0.5
# Go to an escape room
# social
# 0.6
# Learn the Chinese erhu
# music
# 0.6
# Learn the Chinese erhu
# music
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.8
# Go see a Broadway production
# recreational
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.6
# Go to a concert with some friends
# social
# 0.6
# Learn the Chinese erhu
# music
# 0.5
# Donate to your local food bank
# charity
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.5
# Go to an escape room
# social
# 0.6
# Learn the Chinese erhu
# music
# 0.6
# Learn the Chinese erhu
# music
# 0.5
# Go to an escape room
# social
# 0.5
# Donate to your local food bank
# charity
# 0.55
# Learn to play a new instrument
# music
# 0.8
# Go see a Broadway production
# recreational
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.8
# Go see a Broadway production
# recreational
# 0.6
# Go to a concert with some friends
# social
# 0.5
# Donate to your local food bank
# charity
# 0.8
# Go see a Broadway production
# recreational
# 0.8
# Go see a Broadway production
# recreational
# 0.8
# Go see a Broadway production
# recreational
# 0.8
# Go see a Broadway production
# recreational
# 0.5
# Donate to your local food bank
# charity
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.6
# Learn the Chinese erhu
# music
# 0.5
# Donate to your local food bank
# charity
# 0.5
# Donate to your local food bank
# charity
# 0.6
# Learn the Chinese erhu
# music
# 0.6
# Go to a concert with some friends
# social
# 0.6
# Go to a concert with some friends
# social
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.5
# Go to an escape room
# social
# 0.6
# Go to a concert with some friends
# social
# 0.5
# Go to an escape room
# social
# 0.5
# Go to an escape room
# social
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.6
# Learn the Chinese erhu
# music
# 0.6
# Go to a concert with some friends
# social
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.5
# Go to an escape room
# social
# 0.5
# Prepare a 72-hour kit
# busywork
# 0.55
# Learn to play a new instrument
# music
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.55
# Learn to play a new instrument
# music
# 0.8
# Go see a Broadway production
# recreational
# 0.6
# Go to a concert with some friends
# social
# 0.55
# Learn to play a new instrument
# music
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.6
# Learn the Chinese erhu
# music
# 0.8
# Go see a Broadway production
# recreational
# 0.6
# Learn the Chinese erhu
# music
# 0.5
# Go to a karaoke bar with some friends
# social
# 0.5
# Donate to your local food bank
# charity
# 0.55
# Learn to play a new instrument
# music
# 0.8
# Go see a Broadway production
# recreational
# 0.8
# Go see a Broadway production
# recreational
# 0.6
# Learn the Chinese erhu
# music
# 0.8
# Go see a Broadway production
# recreational

# %% [markdown]
# ### Ejercicio 4
#
# Una del espacio.
#
#
# SWAPI es la Star Wars API, quizás la primera fuente de datos accesible de forma programática sobre el universo Star Wars. Esta API no requiere autenticación y está ubicada en la URL: `https://swapi.dev/api/`.
#
# Puedes consultar la documentación de la API en https://swapi.dev/documentation. Verás que la API permite consultar sobre los siguientes *atributes* (en inglés):
#
# - **films** -- The URL root for Film resources
# - **people** -- The URL root for People resources
# - **planets** -- The URL root for Planet resources
# - **species** -- The URL root for Species resources
# - **starships** -- The URL root for Starships resources
# - **vehicles** -- The URL root for Vehicles resources
#
#
# Por una parte, usando la url `https://swapi.dev/api/<atribute>` podemos interrogar a la API sobre todos los elementos de un atributo. Si añadimos un `/<id>` a la url, podemos interrogar sobre un elemento  en particular.
#
# Así, por ejemplo, `https://swapi.dev/api/<atribute>/<id>/`, con el *slug* de *atribute* igual a `people`, y el *slug* de `id` igual a 1, devolverá la información relativa al personaje con identificador 1.
#
# a) Obtén una variable con una cadena de texto o `string`, que contenga solo el nombre del personaje número 1 obtenido de forma programática mediante el acceso a la API via `requests`.
#
#
# Nota: Se denomina usualmente un slug como una parte de una url, o un nombre corto de una url. El término proviene del mundo editorial y se usa extensivamente en internet. Puedes buscar más información en https://en.wikipedia.org/wiki/Slug_(publishing)
#
# **(0.5 puntos)** <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 2px; ">EG</span>

# %%
# Respuesta
response = requests.get('https://swapi.dev/api/people/1/')
print(response.json()['name'])
# Out:
# Luke Skywalker

# %% [markdown]
# b) Construye una lista con la información de todos los personahes. Organiza tu código con funciones que te ayuden a realizar las solicitudes. Ten en cuenta que los resultados pueden estar paginados (solo se muestra una parte de resultados en cada solicitud).
#
# ¿Cuántos personajes has recuperado?
#
# **(1.5 puntos)** <span style="font-family: Courier New; background-color:  #ffcc5c; color: #000000; padding: 3px; ">EG</span>

# %%
# Respuesta
def getAllCharacters(n):
    response = requests.get(f'https://swapi.dev/api/people/{n}/')
    if response.status_code != 200:
        return False
    else:
        print(response.text)
        return True
        

c = True
n = 1
while c:
    c = getAllCharacters(n)
    n+=1
# Out:
# {"name":"Luke Skywalker","height":"172","mass":"77","hair_color":"blond","skin_color":"fair","eye_color":"blue","birth_year":"19BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":["https://swapi.dev/api/vehicles/14/","https://swapi.dev/api/vehicles/30/"],"starships":["https://swapi.dev/api/starships/12/","https://swapi.dev/api/starships/22/"],"created":"2014-12-09T13:50:51.644000Z","edited":"2014-12-20T21:17:56.891000Z","url":"https://swapi.dev/api/people/1/"}
# {"name":"C-3PO","height":"167","mass":"75","hair_color":"n/a","skin_color":"gold","eye_color":"yellow","birth_year":"112BBY","gender":"n/a","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/4/","https://swapi.dev/api/films/5/","https://swapi.dev/api/films/6/"],"species":["https://swapi.dev/api/species/2/"],"vehicles":[],"starships":[],"created":"2014-12-10T15:10:51.357000Z","edited":"2014-12-20T21:17:50.309000Z","url":"https://swapi.dev/api/people/2/"}
# {"name":"R2-D2","height":"96","mass":"32","hair_color":"n/a","skin_color":"white, blue","eye_color":"red","birth_year":"33BBY","gender":"n/a","homeworld":"https://swapi.dev/api/planets/8/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/4/","https://swapi.dev/api/films/5/","https://swapi.dev/api/films/6/"],"species":["https://swapi.dev/api/species/2/"],"vehicles":[],"starships":[],"created":"2014-12-10T15:11:50.376000Z","edited":"2014-12-20T21:17:50.311000Z","url":"https://swapi.dev/api/people/3/"}
# {"name":"Darth Vader","height":"202","mass":"136","hair_color":"none","skin_color":"white","eye_color":"yellow","birth_year":"41.9BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":[],"starships":["https://swapi.dev/api/starships/13/"],"created":"2014-12-10T15:18:20.704000Z","edited":"2014-12-20T21:17:50.313000Z","url":"https://swapi.dev/api/people/4/"}
# {"name":"Leia Organa","height":"150","mass":"49","hair_color":"brown","skin_color":"light","eye_color":"brown","birth_year":"19BBY","gender":"female","homeworld":"https://swapi.dev/api/planets/2/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":["https://swapi.dev/api/vehicles/30/"],"starships":[],"created":"2014-12-10T15:20:09.791000Z","edited":"2014-12-20T21:17:50.315000Z","url":"https://swapi.dev/api/people/5/"}
# {"name":"Owen Lars","height":"178","mass":"120","hair_color":"brown, grey","skin_color":"light","eye_color":"blue","birth_year":"52BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/5/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":[],"starships":[],"created":"2014-12-10T15:52:14.024000Z","edited":"2014-12-20T21:17:50.317000Z","url":"https://swapi.dev/api/people/6/"}
# {"name":"Beru Whitesun lars","height":"165","mass":"75","hair_color":"brown","skin_color":"light","eye_color":"blue","birth_year":"47BBY","gender":"female","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/5/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":[],"starships":[],"created":"2014-12-10T15:53:41.121000Z","edited":"2014-12-20T21:17:50.319000Z","url":"https://swapi.dev/api/people/7/"}
# {"name":"R5-D4","height":"97","mass":"32","hair_color":"n/a","skin_color":"white, red","eye_color":"red","birth_year":"unknown","gender":"n/a","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/1/"],"species":["https://swapi.dev/api/species/2/"],"vehicles":[],"starships":[],"created":"2014-12-10T15:57:50.959000Z","edited":"2014-12-20T21:17:50.321000Z","url":"https://swapi.dev/api/people/8/"}
# {"name":"Biggs Darklighter","height":"183","mass":"84","hair_color":"black","skin_color":"light","eye_color":"brown","birth_year":"24BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/1/"],"species":[],"vehicles":[],"starships":["https://swapi.dev/api/starships/12/"],"created":"2014-12-10T15:59:50.509000Z","edited":"2014-12-20T21:17:50.323000Z","url":"https://swapi.dev/api/people/9/"}
# {"name":"Obi-Wan Kenobi","height":"182","mass":"77","hair_color":"auburn, white","skin_color":"fair","eye_color":"blue-gray","birth_year":"57BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/20/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/4/","https://swapi.dev/api/films/5/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":["https://swapi.dev/api/vehicles/38/"],"starships":["https://swapi.dev/api/starships/48/","https://swapi.dev/api/starships/59/","https://swapi.dev/api/starships/64/","https://swapi.dev/api/starships/65/","https://swapi.dev/api/starships/74/"],"created":"2014-12-10T16:16:29.192000Z","edited":"2014-12-20T21:17:50.325000Z","url":"https://swapi.dev/api/people/10/"}
# {"name":"Anakin Skywalker","height":"188","mass":"84","hair_color":"blond","skin_color":"fair","eye_color":"blue","birth_year":"41.9BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/4/","https://swapi.dev/api/films/5/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":["https://swapi.dev/api/vehicles/44/","https://swapi.dev/api/vehicles/46/"],"starships":["https://swapi.dev/api/starships/39/","https://swapi.dev/api/starships/59/","https://swapi.dev/api/starships/65/"],"created":"2014-12-10T16:20:44.310000Z","edited":"2014-12-20T21:17:50.327000Z","url":"https://swapi.dev/api/people/11/"}
# {"name":"Wilhuff Tarkin","height":"180","mass":"unknown","hair_color":"auburn, grey","skin_color":"fair","eye_color":"blue","birth_year":"64BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/21/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":[],"starships":[],"created":"2014-12-10T16:26:56.138000Z","edited":"2014-12-20T21:17:50.330000Z","url":"https://swapi.dev/api/people/12/"}
# {"name":"Chewbacca","height":"228","mass":"112","hair_color":"brown","skin_color":"unknown","eye_color":"blue","birth_year":"200BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/14/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/6/"],"species":["https://swapi.dev/api/species/3/"],"vehicles":["https://swapi.dev/api/vehicles/19/"],"starships":["https://swapi.dev/api/starships/10/","https://swapi.dev/api/starships/22/"],"created":"2014-12-10T16:42:45.066000Z","edited":"2014-12-20T21:17:50.332000Z","url":"https://swapi.dev/api/people/13/"}
# {"name":"Han Solo","height":"180","mass":"80","hair_color":"brown","skin_color":"fair","eye_color":"brown","birth_year":"29BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/22/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/"],"species":[],"vehicles":[],"starships":["https://swapi.dev/api/starships/10/","https://swapi.dev/api/starships/22/"],"created":"2014-12-10T16:49:14.582000Z","edited":"2014-12-20T21:17:50.334000Z","url":"https://swapi.dev/api/people/14/"}
# {"name":"Greedo","height":"173","mass":"74","hair_color":"n/a","skin_color":"green","eye_color":"black","birth_year":"44BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/23/","films":["https://swapi.dev/api/films/1/"],"species":["https://swapi.dev/api/species/4/"],"vehicles":[],"starships":[],"created":"2014-12-10T17:03:30.334000Z","edited":"2014-12-20T21:17:50.336000Z","url":"https://swapi.dev/api/people/15/"}
# {"name":"Jabba Desilijic Tiure","height":"175","mass":"1,358","hair_color":"n/a","skin_color":"green-tan, brown","eye_color":"orange","birth_year":"600BBY","gender":"hermaphrodite","homeworld":"https://swapi.dev/api/planets/24/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/4/"],"species":["https://swapi.dev/api/species/5/"],"vehicles":[],"starships":[],"created":"2014-12-10T17:11:31.638000Z","edited":"2014-12-20T21:17:50.338000Z","url":"https://swapi.dev/api/people/16/"}

# %% [markdown]
# c) Construye un objeto dataframe de pandas que contenga, `people`, `species`,`classification` (de `species`),`designation` (de `species`) y  `films` a partir de la información de la API. Ten en cuenta que :
#
# - Crea tantas filas como necesites (e.g. si un personaje aparece en dos films).
# - Usa el nombre de cada atributo (e.g. el nombre de propietario) para el contenido del dataframe,  y no su identificador o url.
# - Muestra por pantalla las primeras y las últimas 5 entradas del dataframe.
#
# **(1.5 puntos)** <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">NM</span>

# %%
import pandas as pd

# Respuesta
def createDf(n):
    response = requests.get(f'https://swapi.dev/api/species/{n}/')
    if response.status_code != 200:
        df = pd.DataFrame.from_dict(dataArr)
        print(df.head())
        print(df.tail())
        return False
    else:        
        dataDict["People"].append([requests.get(x).json()['name'] for x in response.json()['people']])
        dataDict["Species"].append(response.json()['name'])
        dataDict["Classification"].append(response.json()['classification'])
        dataDict["Designation"].append(response.json()['designation'])
        dataDict["Films"].append([requests.get(x).json()['title'] for x in response.json()['films']])

        dataArr.append(dataDict)
        return True


dataArr = []
dataDict = {"People":[],"Species":[],"Classification":[],"Designation":[],"Films":[]};
    
c = True
n = 1
while c:
    c = createDf(n)
    dataDict = {"People":[],"Species":[],"Classification":[],"Designation":[],"Films":[]};
    n+=1
# Out:
#                                               People   Species Classification  \
# 0  [[Dormé, Dooku, Bail Prestor Organa, Jocasta Nu]]   [Human]       [mammal]
# 1                     [[C-3PO, R2-D2, R5-D4, IG-88]]   [Droid]   [artificial]
# 2                             [[Chewbacca, Tarfful]]  [Wookie]       [mammal]
# 3                                         [[Greedo]]  [Rodian]     [sentient]
# 4                          [[Jabba Desilijic Tiure]]    [Hutt]    [gastropod]
#
#    Designation                                              Films
# 0   [sentient]  [[A New Hope, The Empire Strikes Back, Return ...
# 1   [sentient]  [[A New Hope, The Empire Strikes Back, Return ...
# 2   [sentient]  [[A New Hope, The Empire Strikes Back, Return ...
# 3  [reptilian]                                     [[A New Hope]]
# 4   [sentient]                 [[A New Hope, Return of the Jedi]]
#             People    Species Classification Designation  \
# 32  [[Wat Tambor]]  [Skakoan]       [mammal]  [sentient]
# 33    [[San Hill]]     [Muun]       [mammal]  [sentient]
# 34    [[Shaak Ti]]  [Togruta]       [mammal]  [sentient]
# 35    [[Grievous]]  [Kaleesh]      [reptile]  [sentient]
# 36  [[Tion Medon]]   [Pau'an]       [mammal]  [sentient]
#
#                                             Films
# 32  [[Attack of the Clones, Revenge of the Sith]]
# 33  [[Attack of the Clones, Revenge of the Sith]]
# 34  [[Attack of the Clones, Revenge of the Sith]]
# 35                        [[Revenge of the Sith]]
# 36                        [[Revenge of the Sith]]

# %% [markdown]
# ### Ejercicio 5
#
#
# En los ejercicios anteriores, hemos utilizado directamente una API para hacer solicitudes a servicios en línea, y nos encargamos directamente de la gestión de los datos de salida.
#
# Sin embargo, también hemos visto en los materiales del curso el uso de librerías que facilitan el acceso a una API, como *tweepy*.
#
# La mayoría de estas librerías (y la mayoría de APIs de proyectos populares) requieren un registro en una web de desarrolladores o API Key.
#
# En este ejercicio os proponemos el uso de geopy https://geopy.readthedocs.io en conjunción con una API, Open Notify, que contiene la información tanto sobre los humanos residentes fuera de la tierra (es decir, en el espacio) como de la posición de la estación internacional Espacial. [Open Notify](http://api.open-notify.org).
#
# Programa una función que obtenga la  longitud y latitud de la posición sobre la que está volando la ISS. Calcula, de forma aproximada su velocidad (suponiendo que estuviera en la superficie de la tierra), obteniendo dos localizaciones consecutivas dentro de un intervalo de tiempo, y calculando la distancia entre estas.
#
# Puedes guiarte con estas dos funciones:
#
# - la función `sleep` del módulo `time`, para pausar un número de segundos.
# - la función `distance` del module `geopy.distance` para calcular la distancia entre dos localizaciones en el globo.
#
#
# **(1.5 puntos)** <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 2px; ">EG</span>

# %%
import time
from geopy import distance

# Resultado
response = requests.get('http://api.open-notify.org/iss-now.json')
print(response.json()['iss_position'])
p1 = (response.json()['iss_position']['latitude'], response.json()['iss_position']['longitude'])

time.sleep(5)

response = requests.get('http://api.open-notify.org/iss-now.json')
print(response.json()['iss_position'])
p2 = (response.json()['iss_position']['latitude'], response.json()['iss_position']['longitude'])

print('Speed:', (distance.distance(p1, p2).m)/5, 'm/s')
# Out:
# {'latitude': '43.4001', 'longitude': '60.0154'}
# {'latitude': '43.5676', 'longitude': '60.3758'}
# Speed: 6917.717283837085 m/s

# %% [markdown]
# ### Ejercicio 6
#
# El  New Mexico Tech Seismological Observatory almacena un registro de eventos sísmicos recientes. Este registro está disponible, por ejemplo en esta web.
#
# - https://geoinfo.nmt.edu/nmtso/events/home.cfml
#
#
#
# Usa `scrappy` para mostrar la información del listado por pantalla de las "Date+Time (UTC)" de cada evento de la página.
#
#
#
# Para ello:
#
# - Utiliza el tutorial de Scrappy para encontrar un `xpath` que contenga la información requerida.
# - Muestra la información requerida en forma de diccionario.
#
# **(1 punto)** <span style="font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px; ">EI</span>

# %%
import scrapy
from scrapy import Selector

# Respuesta
response = requests.get('https://geoinfo.nmt.edu/nmtso/events/home.cfml')
htmlResponse = Selector(text = response.text)

tbodys = htmlResponse.xpath('//tbody')

dataDay = {'Date+Time (UTC)':[]}
for tr in tbodys.xpath('.//tr/td[1]/text()'):
    dataDay['Date+Time (UTC)'].append(tr.get())
    
print(dataDay)
# Out:
# {'Date+Time (UTC)': ['2021-09-28 10:14:37.200', '2021-09-27 11:20:41.900', '2021-09-26 16:26:26.600', '2021-09-26 16:19:25.0', '2021-09-25 21:50:04.300', '2021-09-23 00:44:34.700', '2021-09-22 22:05:56.300', '2021-09-22 03:20:19.0', '2021-09-22 00:25:44.500', '2021-09-21 08:15:45.100', '2021-09-21 04:19:43.500', '2021-09-20 23:31:45.800', '2021-09-20 17:46:29.200', '2021-09-20 09:48:36.700', '2021-09-19 12:37:22.0', '2021-09-18 21:14:11.700', '2021-09-18 15:51:27.0', '2021-09-17 17:37:17.500', '2021-09-16 21:41:49.700', '2021-09-15 09:40:38.700', '2021-09-13 13:28:36.900', '2021-09-13 11:36:02.700', '2021-09-13 05:56:08.0', '2021-09-12 06:24:33.100', '2021-09-11 00:27:06.500', '2021-09-10 22:13:09.900', '2021-09-10 20:13:10.300', '2021-09-10 11:51:14.800', '2021-09-10 11:20:39.100', '2021-09-10 00:41:11.900', '2021-09-09 22:04:38.700', '2021-09-09 04:03:14.100', '2021-09-09 01:26:49.700', '2021-09-08 23:47:13.900', '2021-09-08 06:41:58.800', '2021-09-08 03:37:06.300', '2021-09-08 00:24:33.600', '2021-09-07 09:47:16.600', '2021-09-07 08:29:09.300', '2021-09-05 21:23:40.700', '2021-09-05 16:06:53.500', '2021-09-05 15:20:57.0', '2021-09-05 11:59:29.600', '2021-09-03 08:47:54.800', '2021-09-03 03:05:39.800', '2021-09-02 05:27:09.600', '2021-09-01 21:47:32.600', '2021-09-01 17:52:40.700', '2021-09-01 08:54:10.600', '2021-09-01 07:19:23.300', '2021-08-31 10:17:19.400', '2021-08-30 12:43:02.100', '2021-08-28 19:59:56.200', '2021-08-27 06:48:11.700', '2021-08-26 04:18:49.0', '2021-08-26 02:16:36.300', '2021-08-24 10:08:12.400', '2021-08-24 06:14:25.900', '2021-08-22 08:24:54.600', '2021-08-22 04:23:09.600', '2021-08-21 05:08:34.800', '2021-08-17 22:24:07.900', '2021-08-15 14:56:22.600', '2021-08-15 08:32:43.200', '2021-08-13 04:54:45.0', '2021-08-13 00:54:55.900', '2021-08-12 19:24:14.100', '2021-08-10 07:29:46.100', '2021-08-06 10:31:17.800', '2021-08-04 06:53:57.400', '2021-08-04 03:06:21.700', '2021-07-31 11:43:21.700', '2021-07-31 11:29:50.200', '2021-07-28 23:50:22.900', '2021-07-28 19:20:39.800', '2021-07-25 15:13:31.500', '2021-07-22 12:44:18.100', '2021-07-21 17:30:39.100', '2021-07-19 11:23:25.800', '2021-07-13 19:49:38.200', '2021-07-11 21:05:37.800', '2021-07-09 07:03:50.900', '2021-07-08 04:10:58.0', '2021-07-03 23:46:12.0', '2021-07-01 02:51:28.700', '2021-05-16 16:56:44.200', '2021-05-13 04:53:49.800', '2021-05-11 22:47:20.400', '2021-05-10 11:47:47.800', '2021-05-10 04:36:41.200', '2021-04-15 15:22:01.900', '2021-04-15 05:53:35.300', '2021-03-19 14:18:20.200', '2021-03-19 08:02:15.0', '2021-03-19 02:43:28.300', '2021-02-27 07:44:27.200', '2021-02-22 07:51:38.500', '2021-02-17 00:08:00.900', '2021-02-12 15:59:48.400', '2021-02-11 10:47:19.400', '2021-02-11 08:47:36.500', '2021-02-10 19:59:48.0', '2021-02-10 09:38:00.600', '2021-02-08 08:01:24.100', '2021-01-08 04:37:32.500', '2020-12-26 01:54:42.300', '2020-12-23 11:01:17.500', '2020-12-23 10:57:40.600', '2020-11-24 08:21:18.900', '2020-11-18 04:28:46.0', '2020-11-12 15:22:08.800', '2020-11-12 11:51:00.0', '2020-11-09 02:25:23.0', '2020-11-06 01:25:01.200', '2020-11-03 23:41:54.700', '2020-11-01 21:09:19.200', '2020-10-30 14:41:36.400', '2020-10-28 07:56:18.100', '2020-10-16 07:45:40.500', '2020-10-12 04:03:19.800', '2020-10-11 18:05:16.100', '2020-10-01 20:58:21.800', '2020-10-01 20:49:26.400']}

# %% [markdown]
# ### Ejercicio opcional

# %% [markdown]
# La [NASA](https://www.nasa.gov) mediate su [API](https://api.nasa.gov) publica cada día una imagen astronómica.
#
# Implementa una función para descargar la imagen y visualizarla dentro del mismo notebook. Deberás obtener una clave para usar la API de la NASA.
#
#
#  <span style="font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px; ">EI</span>

# %% [markdown]
# Bibliography: https://ealizadeh.com/blog/3-ways-to-add-images-to-your-jupyter-notebook

# %%
from IPython import display

# Respuesta
response = requests.get('https://api.nasa.gov/planetary/apod?api_key=ymyjbkGLF6QtYAJftnqYgVGV2c3an7Lt2c2mUXD2&date=2021-09-09')
display.Image(response.json()['url'])
