# %% [markdown]
# <div style="width: 100%; clear: both;">
#     <div style="float: left; width: 50%;">
#        <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
#     </div>
# </div>
#
# <div style="float: right; width: 50%;">
#     <p style="margin: 0; padding-top: 22px; text-align:right;">22.501 · Fundamentos de Programación</p>
#     <p style="margin: 0; text-align:right;">Grado en Ciencia de Datos Aplicada</p>
#     <p style="margin: 0; text-align:right; padding-button: 100px;">Estudios de Informática, Multimedia y Telecomunicación</p>
# </div>
# </div>
# <div style="width: 100%; clear: both;">
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# Fundamentos de Programación
# ============================
#
# PEC 6 - Enunciado
# -----------------------------------------------------
#
# En este Notebook encontraréis el conjunto de actividades evaluables como PEC de la asignatura. Veréis que cada una de ellas tiene asociada una puntuación, que indica el peso que tiene la actividad sobre la nota final de la PEC. Adicionalmente, hay un ejercicio opcional, que no tiene puntuación dentro de la PEC, pero que se valora al final del semestre de cara a conceder las matrículas de honor y redondear las notas finales. Podréis sacar la máxima nota de la PAC sin necesidad de hacer este ejercicio. El objetivo de este ejercicio es que sirva como pequeño reto para los estudiantes que quieran profundizar en el contenido de la asignatura.
#
# Veréis que todas las actividades de la PEC tienen una etiqueta, que indica los recursos necesarios para llevarla a cabo. Hay tres posibles etiquetas:
#
# * <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">NM</span> **Sólo materiales**: las herramientas necesarias para realizar la actividad se pueden encontrar en los materiales de la asignatura.
#
# * <span style = "font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Consulta externa guiada**: la actividad puede requerir hacer uso de herramientas que no se encuentran en los materiales de la asignatura, pero el enunciado contiene indicaciones de dónde o cómo encontrar la información adicional necesaria para resolver la actividad.
#
# * <span style = "font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px;">EI</span> **Consulta externa independiente**: la actividad puede requerir hacer uso de herramientas que no se encuentran en los materiales de la asignatura, y el enunciado puede no incluir la descripción de dónde o cómo encontrar esta información adicional. Será necesario que el estudiante busque esta información utilizando los recursos que se han explicado en la asignatura.
#
# Es importante notar que estas etiquetas no indican el nivel de dificultad del ejercicio, sino únicamente la necesidad de consulta de documentación externa para su resolución. Además, recordad que las **etiquetas son informativas**, pero podréis consultar referencias externas en cualquier momento (aunque no se indique explícitamente) o puede ser que podáis hacer una actividad sin consultar ningún tipo de documentación. Por ejemplo, para resolver una actividad que sólo requiera los materiales de la asignatura, puedéis consultar referencias externas si queréis, ya sea tanto para ayudaros en la resolución como para ampliar el conocimiento!
#
# En cuanto a la consulta de documentación externa en la resolución de los ejercicios, recordad **citar siempre la bibliografía utilizada** para resolver cada actividad.
#
# ---
#
# ## Ejercicios para la PEC
#
# A continuación encontraréis los ejercicios que se deben completar en esta PEC y que forman parte de la evaluación de esta unidad.

# %% [markdown]
# ## Ejercicio 1
#
# En esta PEC trabajaremos con el *dataset* `netflix_dataset`, que contiene información relacionada con las características de las películas y series que ofrece la plataforma Netflix. El conjunto original puede encontrarse en el repositorio de datos de Kaggle [Netflix Movies and TV Shows](https://www.kaggle.com/shivamb/netflix-shows), pero el conjunto de datos que utilizaremos tiene algunas modificaciones.
#
# a) Importa el archivo `netflix_dataset.csv` de la carpeta de datos en un dataframe. Muestra por pantalla el número total de entradas, el número de variables, el nombre de las variables, y las 3 primeras entradas.
#
# **(0.5 puntos)**  <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 2px; ">NM</span>

# %%
import pandas as pd

# Respuesta
netflixDf = pd.read_csv('data/netflix_dataset.csv')
print('Número total de entradas:', netflixDf.shape[0])
print('Número de variables:', netflixDf.shape[1])
print('Nombre de las variables:', list(netflixDf.columns))
netflixDf[:3]
# Out:
# Número total de entradas: 8942
# Número de variables: 12
# Nombre de las variables: ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description']
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %% [markdown]
# b) ¿Hay entradas duplicadas? ¿Cuántas? Crea una lista con el número identificador (*show_id*) de todas las entradas duplicadas y elimina estas entradas del dataset. ¿Cuál es el tamaño del nuevo *dataset*?
#
# **(1 punto)**  <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 2px; ">NM</span>

# %%
# Respuesta
netflixDf_duplicates_id = netflixDf[netflixDf.duplicated(keep=False)][['show_id']]
print('Valors duplicats:', netflixDf_duplicates_id)
print('Número total de entradas amb duplicats:', netflixDf.shape[0])
netflixDf = netflixDf.drop_duplicates()
print('Número total de entradas sense duplicats:', netflixDf.shape[0])
# Out:
# Valors duplicats:      show_id
# 32       s33
# 33       s33
# 40       s40
# 41       s40
# 42       s41
# ...      ...
# 8539   s8407
# 8552   s8420
# 8553   s8420
# 8933   s8800
# 8934   s8800
#
# [262 rows x 1 columns]
# Número total de entradas amb duplicats: 8942
# Número total de entradas sense duplicats: 8811

# %% [markdown]
# ### References
# <a id="">[1]</a>
# pandas.DataFrame.drop_duplicates
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

# %% [markdown]
# c) Para cada columna o variable, muestra el número de datos que faltan y sustitúyelos por [NaN](https://es.wikipedia.org/wiki/NaN) usando [el valor especial NaN de NumPy](NaN). **(1 punto)** <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span>

# %%
import numpy as np

# Respuesta
print(netflixDf.notnull())
netflixDf.fillna(np.nan)
# Out:
#       show_id  type  title  director   cast  country  date_added  \
# 0        True  True   True      True  False     True        True
# 1        True  True   True     False   True     True        True
# 2        True  True   True      True   True    False        True
# 3        True  True   True     False  False    False        True
# 4        True  True   True     False   True     True        True
# ...       ...   ...    ...       ...    ...      ...         ...
# 8937     True  True   True      True   True     True        True
# 8938     True  True   True     False  False    False        True
# 8939     True  True   True      True   True     True        True
# 8940     True  True   True      True   True     True        True
# 8941     True  True   True      True   True     True        True
#
#       release_year  rating  duration  listed_in  description
# 0             True    True      True       True         True
# 1             True    True      True       True         True
# 2             True    True      True       True         True
# 3             True    True      True       True         True
# 4             True    True      True       True         True
# ...            ...     ...       ...        ...          ...
# 8937          True    True      True       True         True
# 8938          True    True      True       True         True
# 8939          True    True      True       True         True
# 8940          True    True      True       True         True
# 8941          True    True      True       True         True
#
# [8811 rows x 12 columns]
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8937   s8803    Movie                 Zodiac    David Fincher
# 8938   s8804   TVShow            Zombie Dumb              NaN
# 8939   s8805    Movie             Zombieland  Ruben Fleischer
# 8940   s8806    Movie                   Zoom     Peter Hewitt
# 8941   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8937  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8938                                                NaN            NaN
# 8939  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8940  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8941  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8937   November 20, 2019          2007      R    158 min
# 8938        July 1, 2019          2018  TV-Y7  2 Seasons
# 8939    November 1, 2019          2009      R     88 min
# 8940    January 11, 2020          2006     PG     88 min
# 8941       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8937                     Cult Movies, Dramas, Thrillers
# 8938             Kids' TV, Korean TV Shows, TV Comedies
# 8939                            Comedies, Horror Movies
# 8940                 Children & Family Movies, Comedies
# 8941     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8937  A political cartoonist, a crime reporter and a...
# 8938  While living alone in a spooky town, a young g...
# 8939  Looking to survive in a world taken over by zo...
# 8940  Dragged from civilian life, a former superhero...
# 8941  A scrappy but poor boy worms his way into a ty...
#
# [8811 rows x 12 columns]

# %% [markdown]
# ## Ejercicio 2
#
#
# En el primer ejercicio hemos hecho una exploración preliminar del *dataset*, hemos identificado duplicados y entradas con datos incompletos. Sin embargo, todavía no hemos explorado los datos en profundidad.

# %% [markdown]
# a) Haz un listado de los tipos de variables que contiene el *dataset*. **(0.5 puntos)**  <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 2px; ">NM</span>

# %%
# Respuesta
v = netflixDf.dtypes.unique()
o = list(netflixDf.columns)

print("There are {} different values in marital:\n{}".format(len(v), v))
print("There are {} different values in marital:\n{}".format(len(o), o))
# Out:
# There are 2 different values in marital:
# [dtype('O') dtype('int64')]
# There are 12 different values in marital:
# ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description']

# %% [markdown]
# b) Para la variable categórica *type* unifica el formato de los elementos. **(1 punto)**  <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 2px; ">NM</span>

# %%
# Respuesta
typeData = netflixDf.type.unique()

netflixDf.loc[(netflixDf.type == "TV Show") | (netflixDf.type == "TVShow") | (netflixDf.type == "tvshow") | 
         (netflixDf.type == "tv show") | (netflixDf.type == "TvShow"), "type"] = "TV Show"
netflixDf.loc[(netflixDf.type == "Movie") | (netflixDf.type == "movie"), "type"] = "Movie"
netflixDf.loc[(netflixDf.type == "Film") | (netflixDf.type == "film"), "type"] = "Film"

# Comprobación

v = netflixDf.type.unique()
print("There are {} different values in marital:\n{}".format(len(v), v))
# Out:
# There are 3 different values in marital:
# ['Movie' 'TV Show' 'Film']

# %% [markdown]
# ## Ejercicio 3
#
# ¿Cuántos países aparecen representados en el catálogo de Netflix? Lístalos en orden alfabético. **(1 punto)**  <span style = "font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px;">EI</span>

# %%
# Respuesta
print(len(netflixDf.sort_values(by=['country'])['country'].unique().tolist()))
print(netflixDf.sort_values(by=['country'])['country'].unique().tolist())
# Out:
# 749
# [', France, Algeria', ', South Korea', 'Argentina', 'Argentina, Brazil, France, Poland, Germany, Denmark', 'Argentina, Chile', 'Argentina, Chile, Peru', 'Argentina, France', 'Argentina, France, United States, Germany, Qatar', 'Argentina, Italy', 'Argentina, Spain', 'Argentina, United States', 'Argentina, United States, Mexico', 'Argentina, Uruguay, Serbia', 'Argentina, Uruguay, Spain, France', 'Argentina, Venezuela', 'Australia', 'Australia, Armenia, Japan, Jordan, Mexico, Mongolia, New Zealand, Philippines, South Africa, Sweden, United States, Uruguay', 'Australia, Canada', 'Australia, France', 'Australia, France, Ireland', 'Australia, Germany', 'Australia, India', 'Australia, Iraq', 'Australia, New Zealand', 'Australia, New Zealand, United States', 'Australia, United Arab Emirates', 'Australia, United Kingdom', 'Australia, United Kingdom, Canada', 'Australia, United Kingdom, United Arab Emirates, Canada', 'Australia, United Kingdom, United States, New Zealand, Italy, France', 'Australia, United States', 'Austria', 'Austria, Czech Republic', 'Austria, Germany', 'Austria, Iraq, United States', 'Austria, United States', 'Bangladesh', 'Belarus', 'Belgium', 'Belgium, France', 'Belgium, France, Netherlands', 'Belgium, Ireland, Netherlands, Germany, Afghanistan', 'Belgium, Netherlands', 'Belgium, United Kingdom', 'Belgium, United Kingdom, United States', 'Brazil', 'Brazil, France', 'Brazil, France, Germany', 'Brazil, India, China, United States', 'Brazil, Netherlands, United States, Colombia, Austria, Germany', 'Brazil, United Kingdom', 'Brazil, United States', 'Bulgaria', 'Bulgaria, United States', 'Bulgaria, United States, Spain, Canada', 'Cambodia', 'Cambodia, United States', 'Cameroon', 'Canada', 'Canada, Australia', 'Canada, Belgium', 'Canada, Brazil', 'Canada, France', 'Canada, France, Italy, Morocco, United States', 'Canada, France, United States', 'Canada, Germany', 'Canada, Germany, France, United States', 'Canada, Germany, South Africa', 'Canada, Hungary, United States', 'Canada, India', 'Canada, India, Thailand, United States, United Arab Emirates', 'Canada, Ireland, United States', 'Canada, Japan, Netherlands', 'Canada, Japan, United States', 'Canada, Luxembourg', 'Canada, Mexico, Germany, South Africa', 'Canada, Nigeria', 'Canada, Nigeria, United States', 'Canada, Norway', 'Canada, South Africa', 'Canada, South Korea, United States', 'Canada, Spain', 'Canada, Spain, France', 'Canada, United Kingdom', 'Canada, United Kingdom, Netherlands', 'Canada, United Kingdom, United States', 'Canada, United States', 'Canada, United States, Cayman Islands', 'Canada, United States, Denmark', 'Canada, United States, France', 'Canada, United States, Germany', 'Canada, United States, India, United Kingdom', 'Canada, United States, Ireland', 'Canada, United States, Mexico', 'Canada, United States, United Kingdom', 'Canada, United States, United Kingdom, France, Luxembourg', 'Chile', 'Chile, Argentina', 'Chile, Argentina, France, Spain, United States', 'Chile, Brazil', 'Chile, France', 'Chile, Italy', 'Chile, Peru', 'Chile, Spain, Argentina, Germany', 'Chile, United States, France', 'China', 'China, Canada, United States', 'China, Germany, India, United States', 'China, Hong Kong', 'China, Hong Kong, United States', 'China, India, Nepal', 'China, Japan', 'China, Morocco, Hong Kong', 'China, South Korea, United States', 'China, Spain, South Korea, United States', 'China, Taiwan', 'China, United Kingdom', 'China, United States', 'China, United States, Australia', 'China, United States, Canada', 'China, United States, United Kingdom', 'Colombia', 'Colombia, Mexico', 'Colombia, Mexico, United States', 'Colombia, Peru, United Kingdom', 'Colombia, United States', 'Croatia', 'Croatia, Slovenia, Serbia, Montenegro', 'Cyprus', 'Czech Republic, France', 'Czech Republic, Slovakia', 'Czech Republic, United Kingdom, France', 'Czech Republic, United Kingdom, United States', 'Czech Republic, United States', 'Denmark', 'Denmark, Brazil, France, Portugal, ...

# %% [markdown]
# ## Ejercicio 4
#
# Explora la variable numérica *release_year* y detecta los valores anómalos que puedas identificar.
#
# **(1 punto)**  <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 2px; ">NM</span>

# %%
# Respuesta
print(netflixDf.loc[(netflixDf.release_year < 1925) | (netflixDf.release_year > 2024), "release_year"].tolist())
# Out:
# [16, 12021, 11255, 3929, 3416, 161, 13062, 46, 8099, 90]

# %% [markdown]
# ## Ejercicio 5
#
# Comenta y explica la función del código siguiente.
#
# **(0.5 puntos)** <span style = "font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px;">EI</span>

# %%
from sklearn.preprocessing import FunctionTransformer

X = np.linspace(0, 1, num=10).reshape((5, 2))

F = FunctionTransformer(np.around, kw_args=dict(decimals=3))

print(F.transform(X))
# Out:
# [[0.    0.111]
#  [0.222 0.333]
#  [0.444 0.556]
#  [0.667 0.778]
#  [0.889 1.   ]]

# %%
# Respuesta
# Primero se importa FunctionTransformer de sklearn
# Segundo se crea una matriz 5x2 de 5 valores con el mismo espacio entre ellos de 0 a 1 (estos incluidos)
# Tercero se crea una variable con FunctionTransformer que redondee con tres decimales
# Se printa la variable de la matrix transformada con la anterior variable creada

# %% [markdown]
# ## Ejercicio 6
#
# Un grupo de antropólogos se pregunta si la producción de películas y series disminuye en épocas de crisis económica y queremos ayudarles a recoger evidencia.
#
# Tendremos que representar la variable `release_year` como una variable discreta, en lugar de continua, ya que nos interesa separar esta información en 3 categorías: *BeforeCrisis*, *DuringCrisis*, *AfterCrisis*.
#
# *BeforeCrisis* recogerá el conjunto de películas anteriores a 2008, *DuringCrisis* aquellas de 2008 a 2013 (ambos años incluidos), y *AfterCrisis* incluirá todas las posteriores a enero de 2014.
#
# a) Crea un nuevo dataset derivado del anterior que incluya también la columna *time_frame* con este etiquetado. **(1 punto)**  <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 2px; ">NM</span>

# %% [markdown]
# ### References
# <a id="">[1]</a>
# Tutorial: Add a Column to a Pandas DataFrame Based on an If-Else Condition
# https://www.dataquest.io/blog/tutorial-add-column-pandas-dataframe-based-on-if-else-condition/

# %%
# Respuesta 
conditions = [(netflixDf.release_year < 2008), (netflixDf.release_year >= 2008) & (netflixDf.release_year <= 2013), (netflixDf.release_year >= 2014)]

time_frameData = ['BeforeCrisis', 'DuringCrisis', 'AfterCrisis']
netflixDf['time_frame'] = np.select(conditions, time_frameData)

netflixDf
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8937   s8803    Movie                 Zodiac    David Fincher
# 8938   s8804  TV Show            Zombie Dumb              NaN
# 8939   s8805    Movie             Zombieland  Ruben Fleischer
# 8940   s8806    Movie                   Zoom     Peter Hewitt
# 8941   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8937  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8938                                                NaN            NaN
# 8939  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8940  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8941  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8937   November 20, 2019          2007      R    158 min
# 8938        July 1, 2019          2018  TV-Y7  2 Seasons
# 8939    November 1, 2019          2009      R     88 min
# 8940    January 11, 2020          2006     PG     88 min
# 8941       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8937                     Cult Movies, Dramas, Thrillers
# 8938             Kids' TV, Korean TV Shows, TV Comedies
# 8939                            Comedies, Horror Movies
# 8940                 Children & Family Movies, Comedies
# 8941     Dramas, International Movies, Music & Musicals
#
#                                             description    time_frame
# 0     As her father nears the end of his life, filmm...   AfterCrisis
# 1     After crossing paths at a party, a Cape Town t...   AfterCrisis
# 2     To protect his family from a powerful drug lor...   AfterCrisis
# 3     Feuds, flirtations and toilet talk go down amo...   AfterCrisis
# 4     In a city of coaching centers known to train I...   AfterCrisis
# ...                                                 ...           ...
# 8937  A political cartoonist, a crime reporter and a...  BeforeCrisis
# 8938  While living alone in a spooky town, a young g...   AfterCrisis
# 8939  Looking to survive in a world taken over by zo...  DuringCrisis
# 8940  Dragged from civilian life, a former superhero...  BeforeCrisis
# 8941  A scrappy but poor boy worms his way into a ty...   AfterCrisis
#
# [8811 rows x 13 columns]

# %% [markdown]
# b) Compara gráficamente el número de películas en cada una de las tres categorías. **(0.5 puntos)**  <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 2px; ">NM</span>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Respuesta
time_frameDict = netflixDf['time_frame'].value_counts().to_dict()

keys = list(time_frameDict.keys())
values = list(time_frameDict.values())

plt.bar(keys, values)
plt.show()

# %% [markdown]
# ## Ejercicio 7
#
# El análisis de sentimientos es el proceso de detección de sentimientos positivos o negativos en el texto. Las empresas lo utilizan a menudo para detectar la opinión en los datos sociales, medir la reputación de la marca y comprender a los clientes. Para procesar texto Python ofrece un paquete integrado llamado re, que se puede usar para trabajar con expresiones regulares. Explora la documentación del [paquete re](https://docs.python.org/es/3/library/re.html).
#
# a) En este ejercicio prepararemos los datos de la columna *description* del dataset para un posterior análisis de sentimientos. Para ello implementa una función que retorne, para cada película o serie, el texto que aparece en la variable *description*, excluyendo cualquier carácter o conjunto de caracteres no alfabéticos (ej. signos de puntuación, números...). Asigna el resultado a una nueva variable del dataset llamada *clean_description*. **(1 punto)**  <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span>

# %%
import re
# Respuesta

def clean_description():
    netflixDfDescriptionCleaned = []
    netflixDfDescription = netflixDf['description'].tolist()
    for x in netflixDfDescription:
        temp = re.sub(r'\W', ' ', x)
        netflixDfDescriptionCleaned.append(temp)
    netflixDf['clean_description'] = netflixDfDescriptionCleaned


clean_description()

# %% [markdown]
# b) Añade al *dataset* la variable booleana *gender_gap* y asígnale el valor True sólo en las películas y series cuya descripción sugiere que participan personajes femeninos. Aplica el método que consideres oportuno e indica el porcentaje de entradas resultantes que cumplen esta condición. **(1 punto)**  <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span>

# %% [markdown]
# ### References
# <a id="">[1]</a>
# gender-guesser 0.4.0
# https://pypi.org/project/gender-guesser/
#
# <a id="">[2]</a>
# What's a good algorithm for people name detection? How can I tell if a string contains a person's name?
# https://www.quora.com/Whats-a-good-algorithm-for-people-name-detection-How-can-I-tell-if-a-string-contains-a-persons-name
#
# <a id="">[3]</a>
# Named Entity Recognition
# https://spacy.io/usage/linguistic-features#named-entities

# %%
# Respuesta
import gender_guesser.detector as gender
import spacy

nlp = spacy.load("en_core_web_trf")
famaleBool = [False] * len(netflixDf['clean_description'])
d = gender.Detector(case_sensitive=False)
for i, x in enumerate(netflixDf['clean_description']):
    doc = nlp(x)
    for ent in doc.ents:
        if ent.label_ == 'PERSON' and (d.get_gender(ent.text) == 'female' or d.get_gender(ent.text) == 'mostly_female'):
            famaleBool[i] = True
            break

netflixDf['gender_gap'] = famaleBool
# Out:
# /home/xavi/miniconda3/envs/uoc_env/lib/python3.6/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %%
netflixDf
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8937   s8803    Movie                 Zodiac    David Fincher
# 8938   s8804  TV Show            Zombie Dumb              NaN
# 8939   s8805    Movie             Zombieland  Ruben Fleischer
# 8940   s8806    Movie                   Zoom     Peter Hewitt
# 8941   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8937  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8938                                                NaN            NaN
# 8939  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8940  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8941  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8937   November 20, 2019          2007      R    158 min
# 8938        July 1, 2019          2018  TV-Y7  2 Seasons
# 8939    November 1, 2019          2009      R     88 min
# 8940    January 11, 2020          2006     PG     88 min
# 8941       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8937                     Cult Movies, Dramas, Thrillers
# 8938             Kids' TV, Korean TV Shows, TV Comedies
# 8939                            Comedies, Horror Movies
# 8940                 Children & Family Movies, Comedies
# 8941     Dramas, International Movies, Music & Musicals
#
#                                             description    time_frame  \
# 0     As her father nears the end of his life, filmm...   AfterCrisis
# 1     After crossing paths at a party, a Cape Town t...   AfterCrisis
# 2     To protect his family from a powerful drug lor...   AfterCrisis
# 3     Feuds, flirtations and toilet talk go down amo...   AfterCrisis
# 4     In a city of coaching centers known to train I...   AfterCrisis
# ...                                                 ...           ...
# 8937  A political cartoonist, a crime reporter and a...  BeforeCrisis
# 8938  While living alone in a spooky town, a young g...   AfterCrisis
# 8939  Looking to survive in a world taken over by zo...  DuringCrisis
# 8940  Dragged from civilian life, a former superhero...  BeforeCrisis
# 8941  A scrappy but poor boy worms his way into a ty...   AfterCrisis
#
#                                       clean_description  gender_gap
# 0     As her father nears the end of his life  filmm...       False
# 1     After crossing paths at a party  a Cape Town t...       False
# 2     To protect his family from a powerful drug lor...       False
# 3     Feuds  flirtations and toilet talk go down amo...       False
# 4     In a city of coaching centers known to train I...       False
# ...                                                 ...         ...
# 8937  A political cartoonist  a crime reporter and a...       False
# 8938  While living alone in a spooky town  a young g...       False
# 8939  Looking to survive in a world taken over by zo...       False
# 8940  Dragged from civilian life  a former superhero...       False
# 8941  A scrappy but poor boy worms his way into a ty...       False
#
# [8811 rows x 15 columns]

# %% [markdown]
# ## Ejercicio opcional
#
# Comenta el siguiente código y explica para qué sirve.
#
# <span style="font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px; ">EI</span>

# %%
import pandas as pd
from sklearn import preprocessing

aux = df.values
min_max_scaler = preprocessing.MinMaxScaler()
aux_scaled = min_max_scaler.fit_transform(aux)
d1 = pd.DataFrame(aux_scaled)

# %% [markdown]
# ### Respuesta

# %%
# Respuesta
# Lo que se hace con este código es primero se crea a una variable que se llama 'aux' los valores de un dataframe,
# después se guarda un objeto del paquete 'sklearn' que se llama 'MinMaxScaler' y de este objeto tomamos el
# método 'fit_transform' el que le pasamos la variable 'aux', y lo que hace este método es coger los datos
# que le pasemos y aprenda la media y la varianza de los datos, los estudiará y los transformará según lo aprendido,
# después se creara un nuevo dataframe con los datos nuevos.

# %% [markdown]
# ### References
# <a id="">[1]</a>
# What and why behind fit_transform() and transform() in scikit-learn!
# https://towardsdatascience.com/what-and-why-behind-fit-transform-vs-transform-in-scikit-learn-78f915cf96fe
